# %%
import pandas as pd
import numpy as np
import sqlite3
import os
from fractions import Fraction

def get_ratio(ins,outs):    
    """ Function to display in to out ratio in the format 1:7 """
    if ins==0:
        ratio='0'+':'+str(int(outs))
        return ratio
    elif outs==0:
        ratio=str(int(ins))+':'+'0'
        return ratio
    elif ins==outs:
        ratio='1:1'
        return ratio
    else:
        ratio=str(Fraction(ins/outs).limit_denominator(1000)).split('/')[0]+':'+str(Fraction(ins/outs).limit_denominator(1000)).split('/')[1]
        return ratio

# %%
data_path='/Users/anastasiaclark/irs_nyc_migration/data'
db='irsmig_county_database'
con = sqlite3.connect(os.path.join(data_path,db,"irs_migration_county.sqlite"))
metros=pd.read_csv(os.path.join(data_path,'metros','metros_basic.csv'),converters={'fips':str,'co_code':str,'cbsa_code':str})

# %%
metros.head()
# Out:
#   cbsa_code     cbsa_name                    metro_micro              co_name  \
# 0     10100  Aberdeen, SD  Micropolitan Statistical Area         Brown County
# 1     10100  Aberdeen, SD  Micropolitan Statistical Area       Edmunds County
# 2     10140  Aberdeen, WA  Micropolitan Statistical Area  Grays Harbor County
# 3     10180   Abilene, TX  Metropolitan Statistical Area      Callahan County
# 4     10180   Abilene, TX  Metropolitan Statistical Area         Jones County
#
#         st_name  st_code co_code   fips
# 0  South Dakota       46     013  46013
# 1  South Dakota       46     045  46045
# 2    Washington       53     027  53027
# 3         Texas       48     059  48059
# 4         Texas       48     253  48253

# %%
years=['2011_12','2012_13','2013_14','2014_15'] # project years 

# for year in years:
year=years[3]
table1='outflow_{}'.format(year)
table2='inflow_{}'.format(year)

# %%
df_out = pd.read_sql_query("SELECT * from {} where {}.origin!={}.destination".format(table1, table1, table1), con)
df_in=pd.read_sql_query("SELECT * from {} where {}.origin!={}.destination".format(table2, table2, table2), con)

# %%
# Make the index to be same for same records
df_out['uid']=df_out.origin+"_"+df_out.destination
df_in['uid']=df_in.origin+"_"+df_in.destination
df_in.set_index('uid', inplace=True)
df_out.set_index('uid', inplace=True)

# %%
# NYC counties
nyc=['36005','36047','36061','36081','36085']

# %%
nyc_in=df_in[(df_in['destination'].isin(nyc)) & (~df_in['origin'].isin(nyc))]
nyc_out=df_out[(df_out['origin'].isin(nyc)) & (~df_out['destination'].isin(nyc))]

# %%
to_nyc=nyc_in[['origin','co_orig_name','exemptions','st_orig_abbrv']].groupby(['origin','co_orig_name','st_orig_abbrv']).sum().sort_values('exemptions',ascending=False).reset_index()
from_nyc=nyc_out[['destination','co_dest_name','st_dest_abbrv','exemptions']].groupby(['destination','co_dest_name','st_dest_abbrv']).sum().sort_values('exemptions',ascending=False).reset_index()
to_nyc.rename(columns={'origin':'co_fips','co_orig_name':'co_name','exemptions':'inflow','st_orig_abbrv':'state'},inplace=True)
from_nyc.rename(columns={'destination':'co_fips','co_dest_name':'co_name','st_dest_abbrv':'state','exemptions':'outflow'},inplace=True)

# %%
nyc_in.head()
# Out:
#             st_dest_abbrv destination origin st_orig_abbrv  \
# uid
# 36119_36005            NY       36005  36119            NY
# 48453_36005            NY       36005  48453            TX
# 34017_36005            NY       36005  34017            NJ
# 34003_36005            NY       36005  34003            NJ
# 36059_36005            NY       36005  36059            NY
#
#                    co_orig_name  returns  exemptions   income  disclosure
# uid
# 36119_36005  Westchester County   2088.0      3835.0  85250.0         NaN
# 48453_36005       Travis County    414.0       806.0   6474.0         NaN
# 34017_36005       Hudson County    329.0       591.0  10113.0         NaN
# 34003_36005       Bergen County    297.0       539.0  11758.0         NaN
# 36059_36005       Nassau County    284.0       502.0  11835.0         NaN

# %%
nyc_in['destination']='nyc'
nyc_in.exemptions

# %%
to_nyc.head()
# Out:
#   co_fips                        co_name state   inflow
# 0   59000  Other flows - Different State    DS  19743.0
# 1   36059                  Nassau County    NY  11900.0
# 2   36119             Westchester County    NY   9048.0
# 3   36103                 Suffolk County    NY   5837.0
# 4   34017                  Hudson County    NJ   4709.0

# %%
flows_nyc = to_nyc.merge(from_nyc, on=['co_fips', 'co_name', 'state'], how='outer')

# %%
flows_nyc[['co_name','state','inflow']].sort_values('inflow', ascending=False).head(n=10)
# Out:
#                          co_name state   inflow
# 0  Other flows - Different State    DS  19743.0
# 1                  Nassau County    NY  11900.0
# 2             Westchester County    NY   9048.0
# 3                 Suffolk County    NY   5837.0
# 4                  Hudson County    NJ   4709.0
# 5                  Bergen County    NJ   3860.0
# 6             Los Angeles County    CA   3465.0
# 7                  Travis County    TX   3067.0
# 8               Fairfield County    CT   2966.0
# 9             Foreign - Overseas    FR   2872.0

# %%
# most of the top senders to NYC are also top receivers of migrants from NYC;
flows_nyc[['co_name','state','outflow']].sort_values('outflow',ascending=False).head(n=10)
# Out:
#                           co_name state  outflow
# 0   Other flows - Different State    DS  23807.0
# 1                   Nassau County    NY  20316.0
# 2              Westchester County    NY  13986.0
# 3                  Suffolk County    NY   8171.0
# 4                   Hudson County    NJ   7273.0
# 9              Foreign - Overseas    FR   6666.0
# 5                   Bergen County    NJ   5816.0
# 6              Los Angeles County    CA   5365.0
# 10                   Essex County    NJ   4791.0
# 8                Fairfield County    CT   4283.0

# %%
# merge metro areas info to nyc flows to determine what counties from thesae flows are urban
flows_nyc=flows_nyc.merge(metros[['cbsa_name','fips']], left_on='co_fips', right_on='fips', how='left').drop('fips',1)

# %%
flows_nyc.head()
# Out:
#   co_fips                        co_name state   inflow  outflow  \
# 0   59000  Other flows - Different State    DS  19743.0  23807.0
# 1   36059                  Nassau County    NY  11900.0  20316.0
# 2   36119             Westchester County    NY   9048.0  13986.0
# 3   36103                 Suffolk County    NY   5837.0   8171.0
# 4   34017                  Hudson County    NJ   4709.0   7273.0
#
#                                cbsa_name
# 0                                    NaN
# 1  New York-Newark-Jersey City, NY-NJ-PA
# 2  New York-Newark-Jersey City, NY-NJ-PA
# 3  New York-Newark-Jersey City, NY-NJ-PA
# 4  New York-Newark-Jersey City, NY-NJ-PA

# %%
# calculate fractions, net flow and ratio
flows_nyc['net_flow'] = flows_nyc.inflow - flows_nyc.outflow
flows_nyc['in_ratio'] = flows_nyc.inflow / flows_nyc.outflow
flows_nyc['out_ratio'] = flows_nyc.outflow / flows_nyc.inflow
# need to fill Nulls with 0 for in and out flow to apply get_ration function
#flows_nyc.inflow.fillna(0, inplace=True)
#flows_nyc.outflow.fillna(0, inplace=True)
#flows_nyc['in_to_out_ratio'] = flows_nyc.apply(lambda x: get_ratio(x['inflow'], x['outflow']), axis=1)
flows_nyc.head()
# Out:
#   co_fips                        co_name state   inflow  outflow  \
# 0   59000  Other flows - Different State    DS  19743.0  23807.0
# 1   36059                  Nassau County    NY  11900.0  20316.0
# 2   36119             Westchester County    NY   9048.0  13986.0
# 3   36103                 Suffolk County    NY   5837.0   8171.0
# 4   34017                  Hudson County    NJ   4709.0   7273.0
#
#                                cbsa_name  net_flow  in_ratio  out_ratio
# 0                                    NaN   -4064.0  0.829294   1.205845
# 1  New York-Newark-Jersey City, NY-NJ-PA   -8416.0  0.585745   1.707227
# 2  New York-Newark-Jersey City, NY-NJ-PA   -4938.0  0.646933   1.545756
# 3  New York-Newark-Jersey City, NY-NJ-PA   -2334.0  0.714356   1.399863
# 4  New York-Newark-Jersey City, NY-NJ-PA   -2564.0  0.647463   1.544489

# %%
# drop a column in each table, so that the columns are the same in both tables
df_in.drop('co_orig_name',1,inplace=True)
df_out.drop('co_dest_name',1,inplace=True)

# %%
# get inflow and outflow into a single table and since most of the records exist in both tables, drop duplicates
flows=pd.concat([df_in,df_out],axis=0).drop_duplicates(subset=['origin','destination','returns','exemptions'])

# %%
# check if there are any records with duplicated indexes
len(flows[flows.index.duplicated()])
# Out:
# 94

# %%
# 94 records have different data in inflow and outflow tables
# get the indices of the non-matching records
non_matching=flows.index[flows.index.duplicated()]

# %%
# look at 10 of them
flows.loc[non_matching].head(n=10)
# Out:
#             destination  disclosure  exemptions    income origin  returns  \
# uid
# 06001_06083       06083         NaN       108.0    3725.0  06001     73.0
# 06001_06083       06083         NaN       112.0    2469.0  06001     74.0
# 06013_06085       06085         NaN      1363.0  256538.0  06013    789.0
# 06013_06085       06085         NaN      1359.0   70854.0  06013    788.0
# 06013_32031       32031         NaN       266.0  155568.0  06013    142.0
# 06013_32031       32031         NaN       261.0   22906.0  06013    141.0
# 06013_06019       06019         NaN       188.0    9401.0  06013     85.0
# 06013_06019       06019         NaN       186.0    3576.0  06013     84.0
# 06013_48113       48113         NaN       104.0   12731.0  06013     52.0
# 06013_48113       48113         NaN       101.0    5569.0  06013     51.0
#
#             st_dest_abbrv st_orig_abbrv
# uid
# 06001_06083            CA            CA
# 06001_06083            CA            CA
# 06013_06085            CA            CA
# 06013_06085            CA            CA
# 06013_32031            NV            CA
# 06013_32031            NV            CA
# 06013_06019            CA            CA
# 06013_06019            CA            CA
# 06013_48113            TX            CA
# 06013_48113            TX            CA

# %%
# looks like the differences in returns and exemptions is small
# compare the difference in returns and exemptions for each of these records
# create a single dataframe of differences by combining each difference between 2 rows
dfs=[]
for ix in non_matching:
    a=flows.loc[ix,['exemptions','returns']]
    d=a.diff()
    dfs.append(d)
df=pd.concat(dfs)

# %%
# difference in exemptions ranges from -6 to 7 and difference in returns ranges from -2 to 2
print 'Max difference in exemptions', df.exemptions.max()
print 'Min difference in exemptions',df.exemptions.min()
print 'Max difference in returns',df.returns.max()
print 'Min difference in returns',df.returns.min()
# Out:
# Max difference in exemptions 7.0
# Min difference in exemptions -6.0
# Max difference in returns 2.0
# Min difference in returns -2.0

# %%
# since the difference is not large, drop one of the duplicated indices from the combined dataframe
print len(flows)
flows = flows[~flows.index.duplicated(keep='first')]
print '94 records have been dropped'
print len(flows)
# Out:
# 54573
# 94 records have been dropped
# 54479

# %%
# merge metro area information twice: for county of origin and for county of destination
flows = flows.merge(metros[['fips', 'cbsa_name']],left_on='destination', right_on='fips', how='left').drop('fips',1).rename(columns={'cbsa_name':'dest_cbsa'})
flows = flows.merge(metros[['fips', 'cbsa_name']],left_on='origin', right_on='fips', how='left').drop('fips',1).rename(columns={'cbsa_name':'orig_cbsa'})

# %%
flows.sort_values('exemptions', ascending=False).head(n=20)
# Out:
#       destination  disclosure  exemptions     income origin  returns  \
# 3891        06071         NaN     30386.0   571995.0  06037  13581.0
# 3412        06059         NaN     28238.0  1039750.0  06037  15621.0
# 53291       59000         NaN     24678.0   501249.0  48453  12369.0
# 2835        06037         NaN     23411.0   824361.0  06059  13709.0
# 7143        12011         NaN     23380.0   613429.0  12086  12655.0
# 37702       48157         NaN     22627.0   788038.0  48201  10309.0
# 27115       36081         NaN     19687.0   436329.0  36047  10576.0
# 40190       48453         NaN     19551.0   433739.0  59000  10325.0
# 2836        06037         NaN     19339.0   393068.0  06071   9425.0
# 3647        06065         NaN     17570.0   357117.0  06071   7994.0
# 39447       48439         NaN     17394.0   423065.0  48113   8800.0
# 37966       48201         NaN     16596.0   515016.0  48157   8433.0
# 13440       17043         NaN     16277.0   593035.0  17031   8441.0
# 8661        12086         NaN     16240.0   389697.0  12011   9024.0
# 3648        06065         NaN     15802.0   381922.0  06037   7430.0
# 37077       48113         NaN     15477.0   478957.0  48439   8301.0
# 26365       36047         NaN     15315.0   997565.0  36061  10955.0
# 3892        06071         NaN     15139.0   384024.0  06065   7032.0
# 36838       48085         NaN     14726.0   522128.0  48113   7541.0
# 25988       36005         NaN     14501.0   231198.0  36061   7355.0
# 1433        04013         NaN     14133.0   516091.0  59000   7929.0
# 38999       48339         NaN     14075.0   537626.0  48201   6689.0
# 26366       36047         NaN     13874.0   297620.0  36081   7969.0
# 45461       59000         NaN     13764.0   378363.0  04013   7456.0
# 18440       24005         NaN     13363.0   325799.0  24510   6650.0
# 26672       36059         NaN     13344.0   499924.0  36081   6446.0
# 3649        06065         NaN     13216.0   307134.0  06059   6079.0
# 13092       17031         NaN     12683.0   530743.0  17043   7461.0
# 43558       53061         NaN     12665.0   455584.0  53033   7169.0
# 5270        08005         NaN     12535.0   366887.0  08031   6631.0
# ...           ...         ...         ...        ...    ...      ...
# 54370       57009        -1.0         NaN        NaN  55113      NaN
# 54373       57009        -1.0         NaN        NaN  55115      NaN
# 54376       57009        -1.0         NaN        NaN  55117      NaN
# 54379       57009        -1.0         NaN        NaN  55119      NaN
# 54382       57009        -1.0         NaN        NaN  55121      NaN
# 54385       57009        -1.0         NaN        NaN  55123      NaN
# 54388       57009        -1.0         NaN        NaN  55125      NaN
# 54391       57009        -1.0         NaN        NaN  55127      NaN
# 54394       57009        -1.0         NaN        NaN  55129      NaN
# 54397       57009        -1.0         NaN        NaN  55131      NaN
# 54401       57009        -1.0         NaN        NaN  55133      NaN
# 54404       57009        -1.0         NaN        NaN  55135      NaN
# 54407       57009        -1.0         NaN        NaN  55137      NaN
# 54413       57009        -1.0         NaN        NaN  55141      NaN
# 54416       57009        -1.0         NaN        NaN  56001      NaN
# 54419       57009        -1.0         NaN        NaN  56003      NaN
# 54422       57009        -1.0         NaN        NaN  56005      NaN
# 54425       57009        -1.0         NaN        NaN  56007      NaN
# 54428       57009        -1.0         NaN        NaN  56009      NaN
# 54433       57009        -1.0         NaN        NaN  56013      NaN
# 54440       57009        -1.0         NaN        NaN  56019      NaN
# 54444       57009        -1.0         NaN        NaN  56021      NaN
# 54447       57009        -1.0         NaN        NaN  56023      NaN
# 54455       57009        -1.0         NaN        NaN  56029      NaN
# 54460       57009        -1.0         NaN        NaN  56033      NaN
# 54465       57009        -1.0         NaN        NaN  56037      NaN
# 54469       57009        -1.0         NaN        NaN  56039      NaN
# 54472       57009        -1.0         NaN        NaN  56041      NaN
# 54475       57009        -1.0         NaN        NaN  56043      NaN
# 54478       57009        -1.0         NaN        NaN  56045      NaN
#
#       st_dest_abbrv st_orig_abbrv                                  dest_cbsa  \
# 3891             CA            CA       Riverside-San Bernardino-Ontario, CA
# 3412             CA            CA         Los Angeles-Long Beach-Anaheim, CA
# 53291            DS            TX                                        NaN
# 2835             CA            CA         Los Angeles-Long Beach-Anaheim, CA
# 7143             FL            FL  Miami-Fort Lauderdale-West Palm Beach, FL
# 37702            TX            TX       Houston-The Woodlands-Sugar Land, TX
# 27115            NY            NY      New York-Newark-Jersey City, NY-NJ-PA
# 40190            TX            DS                      Austin-Round Rock, TX
# 2836             CA            CA         Los Angeles-Long Beach-Anaheim, CA
# 3647             CA            CA       Riverside-San Bernardino-Ontario, CA
# 39447            TX            TX            Dallas-Fort Worth-Arlington, TX
# 37966            TX            TX       Houston-The Woodlands-Sugar Land, TX
# 13440            IL            IL         Chicago-Naperville-Elgin, IL-IN-WI
# 8661             FL            FL  Miami-Fort Lauderdale-West Palm Beach, FL
# 3648             CA            CA       Riverside-San Bernardino-Ontario, CA
# 37077            TX            TX            Dallas-Fort Worth-Arlington, TX
# 26365            NY            NY      New York-Newark-Jersey City, NY-NJ-PA
# 3892             CA            CA       Riverside-San Bernardino-Ontario, CA
# 36838            TX            TX            Dallas-Fort Worth-Arlington, TX
# 25988            NY            NY      New York-Newark-Jersey City, NY-NJ-PA
# 1433             AZ            DS                Phoenix-Mesa-Scottsdale, AZ
# 38999            TX            TX       Houston-The Woodlands-Sugar Land, TX
# 26366            NY            NY      New York-Newark-Jersey City, NY-NJ-PA
# 45461            DS            AZ                                        NaN
# 18440            MD            MD              Baltimore-Columbia-Towson, MD
# 26672            NY            NY      New York-Newark-Jersey City, NY-NJ-PA
# 3649             CA            CA       Riverside-San Bernardino-Ontario, CA
# 13092            IL            IL         Chicago-Naperville-Elgin, IL-IN-WI
# 43558            WA            WA                Seattle-Tacoma-Bellevue, WA
# 5270             CO            CO                 Denver-Aurora-Lakewood, CO
# ...             ...           ...                                        ...
# 54370            FR            WI                                        NaN
# 54373            FR            WI                                        NaN
# 54376            FR            WI                                        NaN
# 54379            FR            WI                                        NaN
# 54382            FR            WI                                        NaN
# 54385            FR            WI                                        NaN
# 54388            FR            WI                                        NaN
# 54391            FR            WI                                        NaN
# 54394            FR            WI                                        NaN
# 54397            FR            WI                                        NaN
# 54401            FR            WI                                        NaN
# 54404            FR            WI                                        NaN
# 54407            FR            WI                                        NaN
# 54413            FR            WI                                        NaN
# 54416            FR            WY                                        NaN
# 54419            FR            WY                                        NaN
# 54422            FR            WY                                        NaN
# 54425            FR            WY                                        NaN
# 54428            FR            WY                                        NaN
# 54433            FR            WY                                        NaN
# 54440            FR            WY                                        NaN
# 54444            FR            WY                                        NaN
# 54447            FR            WY                                        NaN
# 54455            FR            WY                                        NaN
# 54460            FR            WY                                        NaN
# 54465            FR            WY                                        NaN
# 54469            FR            WY                                        NaN
# 54472            FR            WY                                        NaN
# 54475            FR            WY                                        NaN
# 54478            FR            WY                                        NaN
#
#                                        orig_cbsa
# 3891          Los Angeles-Long Beach-Anaheim, CA
# 3412          Los Angeles-Long Beach-Anaheim, CA
# 53291                      Austin-Round Rock, TX
# 2835          Los Angeles-Long Beach-Anaheim, CA
# 7143   Miami-Fort Lauderdale-West Palm Beach, FL
# 37702       Houston-The Woodlands-Sugar Land, TX
# 27115      New York-Newark-Jersey City, NY-NJ-PA
# 40190                                        NaN
# 2836        Riverside-San Bernardino-Ontario, CA
# 3647        Riverside-San Bernardino-Ontario, CA
# 39447            Dallas-Fort Worth-Arlington, TX
# 37966       Houston-The Woodlands-Sugar Land, TX
# 13440         Chicago-Naperville-Elgin, IL-IN-WI
# 8661   Miami-Fort Lauderdale-West Palm Beach, FL
# 3648          Los Angeles-Long Beach-Anaheim, CA
# 37077            Dallas-Fort Worth-Arlington, TX
# 26365      New York-Newark-Jersey City, NY-NJ-PA
# 3892        Riverside-San Bernardino-Ontario, CA
# 36838            Dallas-Fort Worth-Arlington, TX
# 25988      New York-Newark-Jersey City, NY-NJ-PA
# 1433                                         NaN
# 38999       Houston-The Woodlands-Sugar Land, TX
# 26366      New York-Newark-Jersey City, NY-NJ-PA
# 45461                Phoenix-Mesa-Scottsdale, AZ
# 18440              Baltimore-Columbia-Towson, MD
# 26672      New York-Newark-Jersey City, NY-NJ-PA
# 3649          Los Angeles-Long Beach-Anaheim, CA
# 13092         Chicago-Naperville-Elgin, IL-IN-WI
# 43558                Seattle-Tacoma-Bellevue, WA
# 5270                  Denver-Aurora-Lakewood, CO
# ...                                          ...
# 54370                                        NaN
# 54373                                Shawano, WI
# 54376                              Sheboygan, WI
# 54379                                        NaN
# 54382                                        NaN
# 54385                                        NaN
# 54388                                        NaN
# 54391                     Whitewater-Elkhorn, WI
# 54394                                        NaN
# 54397          Milwaukee-Waukesha-West Allis, WI
# 54401          Milwaukee-Waukesha-West Allis, WI
# 54404                                        NaN
# 54407                                        NaN
# 54413            Wisconsin Rapids-Marshfield, WI
# 54416                                Laramie, WY
# 54419                                        NaN
# 54422                               Gillette, WY
# 54425                                        NaN
# 54428                                        NaN
# 54433                               Riverton, WY
# 54440                                        NaN
# 54444                               Cheyenne, WY
# 54447                                        NaN
# 54455                                        NaN
# 54460                               Sheridan, WY
# 54465                           Rock Springs, WY
# 54469                             Jackson, WY-ID
# 54472                               Evanston, WY
# 54475                                        NaN
# 54478                                        NaN
#
# [54479 rows x 10 columns]

# %%
# groupby metro of origin and destination to get flows b/n metro areas
metro_flows=flows[['orig_cbsa','dest_cbsa','returns','exemptions']].groupby(['orig_cbsa','dest_cbsa']).sum().reset_index()

# %%
# some of the largest flows are happening within metro areas
metro_flows.sort_values(by='exemptions', ascending=False).head(n=20)
# Out:
#                                           orig_cbsa  \
# 8396          New York-Newark-Jersey City, NY-NJ-PA
# 501               Atlanta-Sandy Springs-Roswell, GA
# 3225                Dallas-Fort Worth-Arlington, TX
# 13194  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 2291             Chicago-Naperville-Elgin, IL-IN-WI
# 5279           Houston-The Woodlands-Sugar Land, TX
# 3511                     Denver-Aurora-Lakewood, CO
# 9269    Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 7770        Minneapolis-St. Paul-Bloomington, MN-WI
# 1475                 Boston-Cambridge-Newton, MA-NH
# 6929             Los Angeles-Long Beach-Anaheim, CA
# 7560      Miami-Fort Lauderdale-West Palm Beach, FL
# 11163             San Francisco-Oakland-Hayward, CA
# 3623                    Detroit-Warren-Dearborn, MI
# 12094                              St. Louis, MO-IL
# 6873             Los Angeles-Long Beach-Anaheim, CA
# 1012                  Baltimore-Columbia-Towson, MD
# 12997    Virginia Beach-Norfolk-Newport News, VA-NC
# 10268          Riverside-San Bernardino-Ontario, CA
# 9800            Portland-Vancouver-Hillsboro, OR-WA
#
#                                           dest_cbsa   returns  exemptions
# 8396          New York-Newark-Jersey City, NY-NJ-PA  233212.0    405566.0
# 501               Atlanta-Sandy Springs-Roswell, GA   93406.0    185267.0
# 3225                Dallas-Fort Worth-Arlington, TX   80159.0    154677.0
# 13194  Washington-Arlington-Alexandria, DC-VA-MD-WV   81815.0    145500.0
# 2291             Chicago-Naperville-Elgin, IL-IN-WI   72249.0    137514.0
# 5279           Houston-The Woodlands-Sugar Land, TX   52904.0    108839.0
# 3511                     Denver-Aurora-Lakewood, CO   51804.0     96175.0
# 9269    Philadelphia-Camden-Wilmington, PA-NJ-DE-MD   47191.0     80801.0
# 7770        Minneapolis-St. Paul-Bloomington, MN-WI   44241.0     76247.0
# 1475                 Boston-Cambridge-Newton, MA-NH   46008.0     71405.0
# 6929           Riverside-San Bernardino-Ontario, CA   29679.0     64555.0
# 7560      Miami-Fort Lauderdale-West Palm Beach, FL   35308.0     62675.0
# 11163             San Francisco-Oakland-Hayward, CA   36142.0     60991.0
# 3623                    Detroit-Warren-Dearborn, MI   33196.0     60227.0
# 12094                              St. Louis, MO-IL   30796.0     55509.0
# 6873             Los Angeles-Long Beach-Anaheim, CA   29330.0     51649.0
# 1012                  Baltimore-Columbia-Towson, MD   27962.0     51242.0
# 12997    Virginia Beach-Norfolk-Newport News, VA-NC   25317.0     47512.0
# 10268            Los Angeles-Long Beach-Anaheim, CA   22016.0     43398.0
# 9800            Portland-Vancouver-Hillsboro, OR-WA   24062.0     41938.0

# %%
ny_metro_in=metro_flows[(metro_flows.dest_cbsa.str.contains('New York')) & (~metro_flows.orig_cbsa.str.contains('New York'))].copy()
ny_metro_out=metro_flows[(metro_flows.orig_cbsa.str.contains('New York')) & (~metro_flows.dest_cbsa.str.contains('New York'))].copy()

# %%
print ny_metro_in.head()
print ny_metro_out.head()
# Out:
#                              orig_cbsa                              dest_cbsa  \
# 55                           Akron, OH  New York-Newark-Jersey City, NY-NJ-PA
# 122        Albany-Schenectady-Troy, NY  New York-Newark-Jersey City, NY-NJ-PA
# 183                    Albuquerque, NM  New York-Newark-Jersey City, NY-NJ-PA
# 246  Allentown-Bethlehem-Easton, PA-NJ  New York-Newark-Jersey City, NY-NJ-PA
# 374                      Ann Arbor, MI  New York-Newark-Jersey City, NY-NJ-PA
#
#      returns  exemptions
# 55      44.0        67.0
# 122   1064.0      1543.0
# 183     49.0        67.0
# 246   1948.0      3288.0
# 374    122.0       146.0
#                                   orig_cbsa  \
# 8324  New York-Newark-Jersey City, NY-NJ-PA
# 8325  New York-Newark-Jersey City, NY-NJ-PA
# 8326  New York-Newark-Jersey City, NY-NJ-PA
# 8327  New York-Newark-Jersey City, NY-NJ-PA
# 8328  New York-Newark-Jersey City, NY-NJ-PA
#
#                               dest_cbsa  returns  exemptions
# 8324        Albany-Schenectady-Troy, NY   1562.0      2626.0
# 8325  Allentown-Bethlehem-Easton, PA-NJ   3255.0      6069.0
# 8326                      Ann Arbor, MI     83.0       122.0
# 8327                      Asheville, NC     33.0        64.0
# 8328  Atlanta-Sandy Springs-Roswell, GA   3511.0      6628.0

# %%
ny_metro_in=ny_metro_in[['orig_cbsa','exemptions']].rename(columns={'orig_cbsa':'metro_name','exemptions':'inflow'})
ny_metro_out=ny_metro_out[['dest_cbsa','exemptions']].rename(columns={'dest_cbsa':'metro_name','exemptions':'outflow'})

# %%
ny_by_metro=pd.merge(ny_metro_in, ny_metro_out, on='metro_name', how='outer')
ny_by_metro.head(n=10)
# Out:
#                           metro_name  inflow  outflow
# 0                          Akron, OH    67.0      NaN
# 1        Albany-Schenectady-Troy, NY  1543.0   2626.0
# 2                    Albuquerque, NM    67.0      NaN
# 3  Allentown-Bethlehem-Easton, PA-NJ  3288.0   6069.0
# 4                      Ann Arbor, MI   146.0    122.0
# 5                      Asheville, NC    32.0     64.0
# 6  Atlanta-Sandy Springs-Roswell, GA  2615.0   6628.0
# 7        Atlantic City-Hammonton, NJ   920.0    718.0
# 8              Austin-Round Rock, TX  5231.0   6245.0
# 9      Baltimore-Columbia-Towson, MD  2996.0   2903.0

# %%
# since some metro areas don't send or don't recieve migrants from NY metro, replace NaN with 0
ny_by_metro.fillna(0,inplace=True)
ny_by_metro['net_flow']=ny_by_metro.inflow-ny_by_metro.outflow

# %%
# top 10 senders to NY metro have negative net flow 
ny_by_metro.sort_values(['inflow','outflow'],ascending=False).head(n=10)
# Out:
#                                        metro_name  inflow  outflow  net_flow
# 81    Philadelphia-Camden-Wilmington, PA-NJ-DE-MD  9907.0  13870.0   -3963.0
# 65      Miami-Fort Lauderdale-West Palm Beach, FL  9757.0  18596.0   -8839.0
# 122  Washington-Arlington-Alexandria, DC-VA-MD-WV  7660.0   8391.0    -731.0
# 60             Los Angeles-Long Beach-Anaheim, CA  6196.0   9626.0   -3430.0
# 16                Bridgeport-Stamford-Norwalk, CT  5901.0   9683.0   -3782.0
# 8                           Austin-Round Rock, TX  5231.0   6245.0   -1014.0
# 14                 Boston-Cambridge-Newton, MA-NH  5001.0   6138.0   -1137.0
# 116                                   Trenton, NJ  3962.0   4805.0    -843.0
# 3               Allentown-Bethlehem-Easton, PA-NJ  3288.0   6069.0   -2781.0
# 23             Chicago-Naperville-Elgin, IL-IN-WI  3283.0   3761.0    -478.0

# %%
con.close()
